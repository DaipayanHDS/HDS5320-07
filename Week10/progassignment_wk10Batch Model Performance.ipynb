# %% [markdown]
# ## Batch Model Performance - Week10
# ### Author: Daipayan Bera
# ### Date: 04-11-2025

# %%
# %run batch_data_science.ipynb
# Out:
# Trained Model Test Data Accuracy Score : 46.25
#
#               precision    recall  f1-score   support
#
#        False       0.49      0.46      0.47       210
#         True       0.44      0.46      0.45       190
#
#     accuracy                           0.46       400
#    macro avg       0.46      0.46      0.46       400
# weighted avg       0.46      0.46      0.46       400
# Trained Model Test Data Accuracy Score : 89.0
#
#               precision    recall  f1-score   support
#
#        False       0.90      0.90      0.90       210
#         True       0.88      0.88      0.88       190
#
#     accuracy                           0.89       400
#    macro avg       0.89      0.89      0.89       400
# weighted avg       0.89      0.89      0.89       400
# Trained Model Test Data Accuracy Score : 91.0
#
#               precision    recall  f1-score   support
#
#        False       0.92      0.90      0.91       503
# ...

# %%
import pandas as pd
scores = pd.DataFrame(result_scores)
scores = scores.T
scores.columns = ["Train", "Accuracy", "Recall", "Precision"]
scores.index.name = "Model"

colors = ["blue", "red", "purple", "green"]

plt.figure(figsize=(10,8))
for col, color in zip(scores.columns, colors):
    plt.plot(scores.index, scores[col], label=col, color=color, linestyle='dashed', marker='o', markerfacecolor=color, markersize=5)

plt.ylabel("Score")
plt.title("Model Performance Metrics")
plt.legend()
plt.grid(True)
plt.ylim(0, 1.1)
plt.show()
